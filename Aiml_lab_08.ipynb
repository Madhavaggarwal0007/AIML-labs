# %% [markdown]
# <a href="https://colab.research.google.com/github/Madhavaggarwal0007/AIML-labs/blob/main/Aiml_lab_08.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
 data = np.array([
 [1,2],[1.5,1.8] , [5,8] , [ 8,8],[1,0.6],
 [9,11] , [8,2] , [10,2] , [9,3] , [ 3,4] ,
[3.5,5], [4.5,5] , [3.8,4.8]
 ])

# %%
 plt.scatter(data[:,0], data[:,1] , s=50 )
 plt.title("Self-Generated Dataset")
 plt.xlabel("Feature1")
 plt.ylabel("Feature2")
 plt.show()

# %%
 kmeans = KMeans(n_clusters=3 , random_state=42)
 kmeans.fit(data)
# Out:
# KMeans(n_clusters=3, random_state=42)

# %%
 centers = kmeans.cluster_centers_
 labels = kmeans.labels_

# %%
 plt.scatter(data[:,0], data[:,1], c=labels, cmap='viridis', s=50) # Corrected the typo 'sactter' to 'scatter'
 plt.scatter(centers[:,0], centers[:,1], color='red', s=200, marker='X')
 plt.title("K-Means Clustering Result(Self - generated data)")
 plt.xlabel('Feature 1')
 plt.ylabel('Feature 2')
 plt.show()
